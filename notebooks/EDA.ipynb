# %%
import pandas as pd

training_data=pd.read_csv("../data/cs-training.csv")

# %%
print(training_data.info())
print(training_data.shape)
print(training_data.isna().sum())
print(training_data.isna().mean())

print(training_data["SeriousDlqin2yrs"].sum())
print(training_data["SeriousDlqin2yrs"].mean())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Unnamed: 0                            150000 non-null  int64
#  1   SeriousDlqin2yrs                      150000 non-null  int64
#  2   RevolvingUtilizationOfUnsecuredLines  150000 non-null  float64
#  3   age                                   150000 non-null  int64
#  4   NumberOfTime30-59DaysPastDueNotWorse  150000 non-null  int64
#  5   DebtRatio                             150000 non-null  float64
#  6   MonthlyIncome                         120269 non-null  float64
#  7   NumberOfOpenCreditLinesAndLoans       150000 non-null  int64
#  8   NumberOfTimes90DaysLate               150000 non-null  int64
#  9   NumberRealEstateLoansOrLines          150000 non-null  int64
#  10  NumberOfTime60-89DaysPastDueNotWorse  150000 non-null  int64
# ...

# %%
training_data.describe().T.reset_index()
# Out:
#                                    index     count          mean  \
# 0                             Unnamed: 0  150000.0  75000.500000
# 1                       SeriousDlqin2yrs  150000.0      0.066840
# 2   RevolvingUtilizationOfUnsecuredLines  150000.0      6.048438
# 3                                    age  150000.0     52.295207
# 4   NumberOfTime30-59DaysPastDueNotWorse  150000.0      0.421033
# 5                              DebtRatio  150000.0    353.005076
# 6                          MonthlyIncome  120269.0   6670.221237
# 7        NumberOfOpenCreditLinesAndLoans  150000.0      8.452760
# 8                NumberOfTimes90DaysLate  150000.0      0.265973
# 9           NumberRealEstateLoansOrLines  150000.0      1.018240
# 10  NumberOfTime60-89DaysPastDueNotWorse  150000.0      0.240387
# 11                    NumberOfDependents  146076.0      0.757222
#
#              std  min           25%           50%            75%        max
# ...

# %%
training_data.groupby(training_data['MonthlyIncome'].isna())['RevolvingUtilizationOfUnsecuredLines'].describe()
# Out:
#                   count      mean         std  min       25%       50%  \
# MonthlyIncome
# False          120269.0  5.899873  257.040685  0.0  0.035084  0.177282
# True            29731.0  6.649421  217.814854  0.0  0.016027  0.081697
#
#                     75%      max
# MonthlyIncome
# False          0.579428  50708.0
# True           0.440549  22198.0

# %%
training_data.groupby(training_data['MonthlyIncome'].isna())['DebtRatio'].describe()
# Out:
#                   count         mean          std  min         25%  \
# MonthlyIncome
# False          120269.0    26.598777   424.446457  0.0    0.143388
# True            29731.0  1673.396556  4248.372895  0.0  123.000000
#
#                        50%          75%       max
# MonthlyIncome
# False             0.296023     0.482559   61106.5
# True           1159.000000  2382.000000  329664.0

# %%
training_data['income_missing']=training_data['MonthlyIncome'].isna()

training_data.groupby('income_missing')['SeriousDlqin2yrs'].agg(
    count='count',
    default='sum',
    default_rate='mean'
)
# Out:
#                  count  default  default_rate
# income_missing
# False           120269     8357      0.069486
# True             29731     1669      0.056137

# %%
training_data['dependents_missing']=training_data['NumberOfDependents'].isna()

training_data.groupby('dependents_missing')['SeriousDlqin2yrs'].agg(
    count='count',
    default='sum',
    default_rate='mean'
)
# Out:
#                      count  default  default_rate
# dependents_missing
# False               146076     9847      0.067410
# True                  3924      179      0.045617

# %%
for col in [
    'NumberOfOpenCreditLinesAndLoans',
    'NumberRealEstateLoansOrLines',
    'NumberOfDependents'
]:
    
    print(f'\n--- {col} ---')
    
    print(
        training_data[col].quantile([
            0.90,
            0.95,
            0.99,
            0.995,
            0.999,
            1.00
        ])
    )
    
    print('\nTop values:')
    print(
        training_data[col]
        .value_counts()
        .sort_index()
        .tail(15)
    )
# Out:
# --- NumberOfOpenCreditLinesAndLoans ---
# 0.900    15.0
# 0.950    18.0
# 0.990    24.0
# 0.995    27.0
# 0.999    34.0
# 1.000    58.0
# Name: NumberOfOpenCreditLinesAndLoans, dtype: float64
#
# Top values:
# NumberOfOpenCreditLinesAndLoans
# 43    8
# 44    2
# 45    8
# 46    3
# 47    2
# 48    6
# 49    4
# 50    2
# 51    2
# 52    3
# 53    1
# 54    4
# 56    2
# 57    2
# 58    1
# Name: count, dtype: int64
#
# --- NumberRealEstateLoansOrLines ---
# 0.900     2.0
# 0.950     3.0
# 0.990     4.0
# 0.995     6.0
# 0.999     9.0
# 1.000    54.0
# Name: NumberRealEstateLoansOrLines, dtype: float64
#
# Top values:
# NumberRealEstateLoansOrLines
# 13    15
# 14     7
# 15     7
# 16     4
# 17     4
# 18     2
# 19     2
# 20     2
# 21     1
# 23     2
# 25     3
# 26     1
# 29     1
# 32     1
# 54     1
# Name: count, dtype: int64
#
# --- NumberOfDependents ---
# 0.900     2.0
# 0.950     3.0
# 0.990     4.0
# 0.995     5.0
# 0.999     6.0
# 1.000    20.0
# ...
